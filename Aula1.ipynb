# %% [markdown]
# ## Inicio aula 1

# %%
import pandas as pd

# %% [markdown]
# *   A variável filmes recebe o arquivo CSV em um DataFrame (tipo uma tabela) contendo os filmes;
# *   A varável avaliacoes recebe outro arquivo contendo as avaliações dos filmes;

# %%
filmes = pd.read_csv("https://raw.githubusercontent.com/alura-cursos/introducao-a-data-science/master/aula0/ml-latest-small/movies.csv")
# filmes é um DataFrame
filmes.columns = ["filmeId", "titulo", "generos"]
filmes.head()
# Out:
#    filmeId  ...                                      generos
# 0        1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1        2  ...                   Adventure|Children|Fantasy
# 2        3  ...                               Comedy|Romance
# 3        4  ...                         Comedy|Drama|Romance
# 4        5  ...                                       Comedy
#
# [5 rows x 3 columns]

# %%
avaliacoes = pd.read_csv("https://github.com/alura-cursos/introducao-a-data-science/blob/master/aula0/ml-latest-small/ratings.csv?raw=true")
avaliacoes.columns = ["usuarioId", "filmeId", "nota", "momento"]
avaliacoes.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %% [markdown]
# O metodo shape retorna a quantidade de linhas e colunas do DataFrame

# %%
avaliacoes.shape
# Out:
# (100836, 4)

# %%
filmes.shape
# Out:
# (9742, 3)

# %% [markdown]
# A variavel notas_medias_por_filme recebe a média das notas agrupadas por filme, ou seja, a média da nota de cada filme

# %%
notas_medias_por_filme = avaliacoes.groupby("filmeId")["nota"].mean()
notas_medias_por_filme.head()
# Out:
# filmeId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: nota, dtype: float64

# %% [markdown]
# Agora vamos juntar a média com seus respectivos filmes.
#
# A variavel filmes_com_media vai receber uma lista, dataFrame, contendo a junção dos filmes com a média calculada

# %%
filmes_com_media = filmes.join(notas_medias_por_filme, on="filmeId")
filmes_com_media.head()
# Out:
#    filmeId  ...      nota
# 0        1  ...  3.920930
# 1        2  ...  3.431818
# 2        3  ...  3.259615
# 3        4  ...  2.357143
# 4        5  ...  3.071429
#
# [5 rows x 4 columns]

# %% [markdown]
# Ordenamos então 15 filmes em ordem Decrescente (da maior nota para a menor)

# %%
filmes_com_media.sort_values("nota", ascending=False).head(15)
# Out:
#       filmeId  ... nota
# 7656    88448  ...  5.0
# 8107   100556  ...  5.0
# 9083   143031  ...  5.0
# 9094   143511  ...  5.0
# 9096   143559  ...  5.0
# 4251     6201  ...  5.0
# 8154   102217  ...  5.0
# 8148   102084  ...  5.0
# 4246     6192  ...  5.0
# 9122   145994  ...  5.0
# 8115   100906  ...  5.0
# 9129   146662  ...  5.0
# 8074    99636  ...  5.0
# 5785    31522  ...  5.0
# 9131   146684  ...  5.0
#
# [15 rows x 4 columns]

# %% [markdown]
# #Desafio 1
# O Paulo fez uma análise rápida e disse que tem 18 filmes sem avaliações, será que ele acertou?
#
# Determine quantos filmes não tem avaliações e quais são esses filmes.

# %%
filmes_sem_nota = filmes_com_media[filmes_com_media['nota'].isna()]['titulo']
filmes_sem_nota
# Out:
# 816                            Innocents, The (1961)
# 2211                                  Niagara (1953)
# 2499                          For All Mankind (1989)
# 2587    Color of Paradise, The (Rang-e khoda) (1999)
# 3118                  I Know Where I'm Going! (1945)
# 4037                              Chosen, The (1981)
# 4506     Road Home, The (Wo de fu qin mu qin) (1999)
# 4598                                  Scrooge (1970)
# 4704                                    Proof (1991)
# 5020                       Parallax View, The (1974)
# 5293                        This Gun for Hire (1942)
# 5421                    Roaring Twenties, The (1939)
# 5452                     Mutiny on the Bounty (1962)
# 5749              In the Realms of the Unreal (2004)
# 5824                        Twentieth Century (1934)
# 5837                       Call Northside 777 (1948)
# 5957                    Browning Version, The (1951)
# 7565                              Chalet Girl (2011)
# ...

# %%
lista_nulo = filmes_com_media['nota'].isnull()
filmes_com_media[lista_nulo]
# Out:
#       filmeId  ... nota
# 816      1076  ...  NaN
# 2211     2939  ...  NaN
# 2499     3338  ...  NaN
# 2587     3456  ...  NaN
# 3118     4194  ...  NaN
# 4037     5721  ...  NaN
# 4506     6668  ...  NaN
# 4598     6849  ...  NaN
# 4704     7020  ...  NaN
# 5020     7792  ...  NaN
# 5293     8765  ...  NaN
# 5421    25855  ...  NaN
# 5452    26085  ...  NaN
# 5749    30892  ...  NaN
# 5824    32160  ...  NaN
# 5837    32371  ...  NaN
# 5957    34482  ...  NaN
# 7565    85565  ...  NaN
#
# [18 rows x 4 columns]

# %% [markdown]
# #Desafio 2
# Mudar o nome da coluna nota do dataframe filmes_com_media para nota_média após o join.

# %%
filmes_com_media.columns = ['filmeId', 'titulo', 'generos', 'nota_media']
filmes_com_media.head()
# Out:
#    filmeId  ... nota_media
# 0        1  ...   3.920930
# 1        2  ...   3.431818
# 2        3  ...   3.259615
# 3        4  ...   2.357143
# 4        5  ...   3.071429
#
# [5 rows x 4 columns]

# %% [markdown]
# #Desafio 3
# Colocar o número de avaliações por filme, isto é, não só a média mas o TOTAL de votos por filme.

# %%
total_votos = avaliacoes.groupby('filmeId')[['usuarioId']].count()
filmes_com_media = filmes_com_media.merge(total_votos, on='filmeId')
filmes_com_media.head()
# Out:
#    filmeId                              titulo  ... nota_media  usuarioId
# 0        1                    Toy Story (1995)  ...   3.920930        215
# 1        2                      Jumanji (1995)  ...   3.431818        110
# 2        3             Grumpier Old Men (1995)  ...   3.259615         52
# 3        4            Waiting to Exhale (1995)  ...   2.357143          7
# 4        5  Father of the Bride Part II (1995)  ...   3.071429         49
#
# [5 rows x 5 columns]

# %%
filmes_com_media.rename(columns={'usuarioId':'votos'}, inplace=True)
filmes_com_media.head()
# Out:
#    filmeId                              titulo  ... nota_media  votos
# 0        1                    Toy Story (1995)  ...   3.920930    215
# 1        2                      Jumanji (1995)  ...   3.431818    110
# 2        3             Grumpier Old Men (1995)  ...   3.259615     52
# 3        4            Waiting to Exhale (1995)  ...   2.357143      7
# 4        5  Father of the Bride Part II (1995)  ...   3.071429     49
#
# [5 rows x 5 columns]

# %%
filmes_com_media["votos"].fillna(0.0, inplace=True)
filmes_com_media.head()
# Out:
#    filmeId                              titulo  ... nota_media  votos
# 0        1                    Toy Story (1995)  ...   3.920930    215
# 1        2                      Jumanji (1995)  ...   3.431818    110
# 2        3             Grumpier Old Men (1995)  ...   3.259615     52
# 3        4            Waiting to Exhale (1995)  ...   2.357143      7
# 4        5  Father of the Bride Part II (1995)  ...   3.071429     49
#
# [5 rows x 5 columns]

# %% [markdown]
# #Desafio 4
# Arredondar as médias (coluna de nota média) para duas casas decimais.

# %%
filmes_com_media.nota_media = filmes_com_media.nota_media.round(2)
filmes_com_media.head()
# Out:
#    filmeId                              titulo  ... nota_media  votos
# 0        1                    Toy Story (1995)  ...       3.92    215
# 1        2                      Jumanji (1995)  ...       3.43    110
# 2        3             Grumpier Old Men (1995)  ...       3.26     52
# 3        4            Waiting to Exhale (1995)  ...       2.36      7
# 4        5  Father of the Bride Part II (1995)  ...       3.07     49
#
# [5 rows x 5 columns]

# %% [markdown]
# #Desafio 5
# Descobrir os generos dos filmes (quais são eles, únicos). (esse aqui o bicho pega)

# %%
#generos = pd.DataFrame()
#generos['generos'] = filmes['generos'].str.split(pat='|').explode().unique()
#generos

generos_df = filmes.generos.str.get_dummies('|')
generos = generos_df.columns
generos.tolist()
# Out:
# ['(no genres listed)',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Children',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Fantasy',
#  'Film-Noir',
#  'Horror',
#  'IMAX',
#  'Musical',
#  'Mystery',
#  'Romance',
#  'Sci-Fi',
#  'Thriller',
#  'War',
#  'Western']

# %% [markdown]
# #Desafio 6
# Contar o número de aparições de cada genero.

# %%
#generos = pd.DataFrame()
#generos['generos'] = filmes['generos'].str.split(pat='|').explode()

total_generos = generos_df.sum().sort_values(ascending=False)
total_generos
# Out:
# Drama                 4361
# Comedy                3756
# Thriller              1894
# Action                1828
# Romance               1596
# Adventure             1263
# Crime                 1199
# Sci-Fi                 980
# Horror                 978
# Fantasy                779
# Children               664
# Animation              611
# Mystery                573
# Documentary            440
# War                    382
# Musical                334
# Western                167
# IMAX                   158
# Film-Noir               87
# (no genres listed)      34
# dtype: int64

# %% [markdown]
# #Desafio 7
# Plotar o gráfico de aparições de cada genero. Pode ser um gráfico de tipo igual a barra.

# %%
total_generos.plot(kind='bar',title='Total de filmes por genero',figsize=(16,6),color='purple')
